# %%
import pandas as pd

# %%
df= pd.DataFrame({
    'speed ups varying number of executors':[1,1.10,1.51,1.55],
    
}, index = [1,2,3,4])
lines = df.plot.line()
lines.set_xlabel("no of executors")
lines.set_ylabel("speedups")
lines.set_title("speedups varying executors graph")
# Out:
# Text(0.5, 1.0, 'speedups varying executors graph')
